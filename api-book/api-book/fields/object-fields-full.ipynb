# %% [markdown]
# (object-field-full:top)=
# # Fields (Full)

# %% [markdown]
# To follow...
#
# ## Making
#
# ### artistMakerPerson
#
# ### artistMakerPeople

# %% [markdown]
# ## Provenance

# %% [markdown]
# ## Connections
