# %% [markdown]
# # Example Queries
#
# Some sample queries. For ease of display of the returned data these request CSV repsonse, which contains only a subset of the full fields available in the JSON response.

# %% [markdown]
# ## Retrieve objects made in France using plywood

# %%
import requests
import pandas as pd
req = pd.read_csv('https://api.vam.ac.uk/v2/objects/search?id_material=AAT12849&id_place=x28849&response_format=csv')
req.head()
# Out:
#   accessionNumber systemNumber objectType _primaryTitle _primaryPlace  \
# 0        W.2-1983       O67165   Armchair         Entas        France
# 1        W.3-1983       O67111   Armchair   Entas chair        France
#
#   _primaryMaker__name _primaryMaker__association  _primaryDate  \
# 0    Goldfinger, Ernö                   designer          1931
# 1    Goldfinger, Ernö                   designer          1931
#
#   _primaryImageId _sampleMaterial _sampleTechnique _sampleStyle  \
# 0      2006AF5010   tubular steel          bending          NaN
# 1      2006AX7623   tubular steel          bending    Modernist
#
#   _currentLocation__displayName  _objectContentWarning  _imageContentWarning
# 0                      In store                  False                 False
# 1                      In store                  False                 False

# %% [markdown]
# ## Retrieve objects made in Edinburgh in the 1920s

# %%
import requests
import pandas as pd
req = pd.read_csv('https://api.vam.ac.uk/v2/objects/search?year_made_from=1920&year_made_to=1920&id_place=x28816&response_format=csv')
req.head(10)
# Out:
#   systemNumber                objectType _primaryTitle _primaryPlace  \
# 0      O144063                    Plaque           NaN     Edinburgh
# 1      O128075  Copy of a Standing Cross           NaN     Edinburgh
# 2       O12315                    Plaque       The Vow     Edinburgh
# 3     O1190238               Watercolour  Plum Blossom     Edinburgh
# 4      O262230         Furnishing fabric      Pastoral     Edinburgh
# 5      O262229         Furnishing fabric       Cockpen     Edinburgh
# 6      O598538                Trade card           NaN     Edinburgh
# 7     O1034483                 bookplate           NaN     Edinburgh
# 8     O1034475                 bookplate           NaN     Edinburgh
# 9     O1034471                 bookplate           NaN     Edinburgh
#
#                _primaryMaker__name _primaryMaker__association  \
# 0            Traquair, Phoebe Anna                      maker
# 1                              NaN                        NaN
# 2            Traquair, Phoebe Anna                  enameller
# 3                Katharine Cameron                     artist
# 4  Charles Francis Annesley Voysey                   designer
# 5  Charles Francis Annesley Voysey                   designer
# 6                          Unknown                        NaN
# 7              Sutherland, John R.                     artist
# 8              Sutherland, John R.                     artist
# 9              Sutherland, John R.                     artist
#
#              _primaryDate _primaryImageId accessionNumber  \
# 0      early 20th century      2007BP4626      M.600-1936
# 1                ca. 1922      2006BK4662  REPRO.A.1923-1
# 2             1900 - 1920      2019ME9874      M.191-1976
# 3  ca. early 20th century      2006BB6291       P.42-1930
# 4                   1920s      2014HD2264   CIRC.857-1967
# 5                ca. 1920      2019LK5720   CIRC.858-1967
# 6               1900-1950      2012FV6000       E.57-1949
# 7           CA. 1902-1926             NaN   CIRC.611-1926
# 8           CA. 1902-1926             NaN   CIRC.613-1926
# 9           CA. 1902-1926             NaN   CIRC.614-1926
#
#                             _currentLocation__textid _currentLocation__site  \
# 0                               THES49618 - In store                     VA
# 1  THES49799 - Cast Courts, The Ruddock Family Ca...                     VA
# 2                              THES252174 - In store                     BH
# 3  THES49654 - Prints & Drawings Study Room, level H                     VA
# 4                               THES50141 - In store                     BH
# 5                               THES50141 - In store                     BH
# 6  THES49171 - Prints & Drawings Study Room, level C                     VA
# 7  THES49654 - Prints & Drawings Study Room, level H                     VA
# 8  THES49654 - Prints & Drawings Study Room, level H                     VA
# 9  THES49654 - Prints & Drawings Study Room, level H                     VA
#
#                        _currentLocation__displayName  \
# 0                                           In store
# 1  Cast Courts, The Ruddock Family Cast Court, Ro...
# 2                                           In store
# 3              Prints & Drawings Study Room, level H
# 4                                           In store
# 5                                           In store
# 6              Prints & Drawings Study Room, level C
# 7              Prints & Drawings Study Room, level H
# 8              Prints & Drawings Study Room, level H
# 9              Prints & Drawings Study Room, level H
#
#    _currentLocation__onDisplay _currentLocation__id _currentLocation__type  \
# 0                        False            THES49618                storage
# 1                         True            THES49799                display
# 2                        False           THES252174                storage
# 3                         True            THES49654                display
# 4                        False            THES50141                storage
# 5                        False            THES50141                storage
# 6                         True            THES49171                display
# 7                         True            THES49654                display
# 8                         True            THES49654                display
# 9                         True            THES49654                display
#
#    _objectContentWarning  _imageContentWarning
# 0                  False                 False
# 1                  False                 False
# 2                  False                 False
# 3                  False                 False
# 4                  False                 False
# 5                  False                 False
# 6                  False                 False
# 7                  False                 False
# 8                  False                 False
# 9                  False                 False

# %% [markdown]
# ## Graph the top 10 materials used in objects made in Wales in the 18th century

# %%
import requests
import pandas as pd
import altair as alt

req = requests.get('https://api.vam.ac.uk/v2/objects/clusters/material/search?id_place=x29337&year_made_from=1700&year_made_to=1800&page_size=10')
object_data = req.json()
object_clusters = object_data["clusters"]
materials = object_clusters["material"]["terms"]

materials_df = pd.DataFrame(materials[0:10])
alt.Chart(materials_df).mark_bar().encode(
    x=alt.X('value', sort='-y', title='Material'),
    y=alt.Y('count', title='Number of Objects')
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Show the changes in object types accessioned throught out the C20th

# %%
# Query per accessioned decade the object types
# Zero out missing values for objects not in that decade per decade
# Draw stacked area graph
