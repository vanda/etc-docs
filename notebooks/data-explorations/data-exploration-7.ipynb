# %%
# BnF
## Data Exploration #7

Exploring the rich collections of the Bibliotech Natalionale de France using the Gallicia portal,

# %%
import sys
sys.path.append("/home/richard/Notebooks/2020/Ivpy/ivpy/src/")

# %%
import requests
from ivpy import attach,show,compose,montage,histogram,scatter
import pandas as pd
import altair as alt
req = pd.read_csv('https://api.vam.ac.uk/v2/objects/search?q=tiger&images_exist=1&response_format=csv&page_size=18')
req.head()
# Out:
#   accessionNumber systemNumber        objectType     _primaryTitle  \
# 0        2545(IS)       O61949  Mechanical organ    Tippoo's Tiger
# 1      IS.60-1968       O17513      A tiger hunt      A tiger-hunt
# 2      FE.69-1997       O22243          Painting  Tiger and Magpie
# 3       25016:756      O633830             Print         THE TIGER
# 4         15607:3      O661487             Print   Head of a Tiger
#
#    _primaryPlace   _primaryMaker__name _primaryMaker__association  \
# 0         Mysore               Unknown                        NaN
# 1         Punjab               Unknown                        NaN
# 2          Korea               Unknown                        NaN
# 3  Great Britain  Whymper, Josiah Wood                     artist
# 4         London      Fairland, Thomas                     artist
#
#    _primaryDate _primaryImageId _sampleMaterial _sampleTechnique _sampleStyle  \
# 0      ca. 1790      2006AH4168            Wood           Carved          NaN
# ...

# %%
IIIF_IMAGE_URL = "https://framemark.vam.ac.uk/collections/%s/full/!100,100/0/default.jpg"
req._primaryImageId = [IIIF_IMAGE_URL % item for item in req._primaryImageId]

# %%
attach(req, "_primaryImageId")
show(cols=3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x600 at 0x7F91F87268B0>
