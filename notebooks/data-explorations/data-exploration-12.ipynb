# %% [markdown]
# # 12. Springtime in Paris
#
# ```{sidebar} Datasets
#   * [Louvre](https://collections.louvre.fr/)
#   * [V&A](https://collections.vam.ac.uk/)
# ```
#
# Even if we cannot travel much at the moment to see the delights of Spring around the world, we can still admire depictions of it in paintings. Let's see how spring compares between the collections in London ([V&A](https://www.vam.ac.uk)) and Paris ([Louvre](https://www.louvre.fr)) collections

# %%
import sys
# You will need to update this you the path for your install - https://github.com/damoncrockett/ivpy/issues
sys.path.append("/path/to/your/ivpy/src")

# %% [markdown]
# ## V&A Collections
#
# First we query the [API](https://developers.vam.ac.uk) for objects of type "Oil painting" and containing the word Spring.

# %%
import pandas as pd
vam_spring_df = pd.read_csv("https://api.vam.ac.uk/v2/objects/search?q=spring&images_exist=true&page=1&kw_object_type=Oil%20painting&response_format=csv")
vam_spring_df.head(10)
# Out:
#   accessionNumber  accessionYear systemNumber    objectType  \
# 0        367-1901         1901.0       O54265  Oil painting
# 1       1601-1869         1869.0      O134110  Oil painting
# 2      E.322-1934         1934.0      O134545  Oil Painting
# 3         CAI.172            NaN       O81631  Oil painting
# 4        144-1888         1888.0      O125151  Oil painting
# 5        224-1879         1879.0       O16546  Oil painting
# 6       FA.187[O]            NaN       O77070  Oil painting
# 7       P.12-1947         1947.0       O17306  Oil painting
# 8       P.70-1986         1986.0       O78693  Oil painting
# 9       FA.241[O]            NaN       O15091  Oil painting
#
#                                        _primaryTitle  _primaryPlace  \
# 0                                             Spring            NaN
# 1                                         The Spring    Switzerland
# 2                                             Spring  Great Britain
# ...

# %%
from ivpy import attach,show

IIIF_IMAGE_URL = "https://framemark.vam.ac.uk/collections/%s/full/!100,100/0/default.jpg"
vam_spring_df._primaryImageId = [IIIF_IMAGE_URL % item for item in vam_spring_df._primaryImageId]
attach(vam_spring_df, "_primaryImageId")
show()
# Out:
# <PIL.Image.Image image mode=RGB size=900x200>

# %% [markdown]
# ## Louvre
#
# The [Louvre](https://www.louvre.fr/) have recently released a new [collections site](https://collections.louvre.fr/) which lets us export search results as a CSV file.

# %% [markdown]
# ```{note}
# This is a cached version of the CSV file because of an issue with [cipher settings](https://askubuntu.com/questions/1231844/ssl-sslerror-ssl-dh-key-too-small-dh-key-too-small-ssl-c1108)
# ```

# %%
#import urllib3
#import requests
import pandas as pd

df_louvre_printemps = pd.read_csv("louvre-spring.csv", sep=";")
df_louvre_printemps.head(15)
# Out:
#             ARK                          Object name/Title  \
# 0   cl010057106                     Le Printemps / Jupiter
# 1   cl010057782                               Le Printemps
# 2   cl010060674                               Le Printemps
# 3   cl010056799                               Le Printemps
# 4   cl010059406                               Le printemps
# 5   cl010067341                               Le printemps
# 6   cl010060578                               Le Printemps
# 7   cl010057734                               Le Printemps
# 8   cl010061105                               Le Printemps
# 9   cl010065015                               Le Printemps
# 10  cl010062521                               Le Printemps
# 11  cl010061819                      Le Printemps et l'Été
# 12  cl010061624          Le Printemps. Bergers et bergères
# 13  cl010063018  Printemps. East Bergholt Common (Suffolk)
# 14  cl010063616        Rosny. Vue du village au printemps.
#
# ...

# %% [markdown]
# ## Lineup
#
# We can explore the CSV a litte more using the excellent [Lineup widget](https://lineup.js.org/)

# %%
# Not Currently working - any fix for lineup_widget welcome! - https://github.com/lineupjs/lineup_widget

#import lineup_widget
#import pandas as pd

#w = lineup_widget.LineUpWidget(df_louvre_printemps)
#w.on_selection_changed(lambda selection: print(selection))
#w

# %% [markdown]
# ## Spring in East Bergholt
#
# An item in common in both collections is a work by [John Constable](https://www.vam.ac.uk/collections/john-constable). At the moment we can't bring the two object images together side-by-side to compare them, but we can look at the V&A [painting](https://collections.vam.ac.uk/item/O125151) here using [IIIF](https://iiif.io/):

# %%
from IPython.display import Image

Image(url = "https://framemark.vam.ac.uk/collections/2006BC6067/full/600,/0/default.jpg")
# Out:
# <img src="https://framemark.vam.ac.uk/collections/2006BC6067/full/600,/0/default.jpg"/>

# %% [markdown]
# and you can see the Louvre version (a copy after the engraving by David Lucas) on [their website](https://collections.louvre.fr/en/ark:/53355/cl010063018).

# %% [markdown]
# ## Springtime in Paris / Paris in Springtime
#
# Further work is needed to identify the best depicition of Paris in Springtime.

# %% [markdown]
# # Notebook Updates
#
# ## 24 June 2024
#
#   * Commented out lineup widget code as just not working currently
