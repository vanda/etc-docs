# %% [markdown]
# # 12. Springtime in Paris
#
# ```{sidebar} Datasets
#   * [Louvre](https://collections.louvre.fr/)
#   * [V&A](https://collections.vam.ac.uk/)
# ```
#
# ```{sidebar} Applications
#   * [Lineup](https://lineup.js.org/)
# ```

# %%
import pandas as pd
df_spring = pd.read_csv("https://api.vam.ac.uk/v2/objects/search?q=spring&images_exist=true&page=1&kw_object_type=Oil%20painting&response_format=csv")
df_spring
# Out:
#    accessionNumber systemNumber    objectType  \
# 0        1601-1869      O134110  Oil painting
# 1         367-1901       O54265  Oil painting
# 2       E.322-1934      O134545  Oil Painting
# 3          CAI.172       O81631  Oil painting
# 4         144-1888      O125151  Oil painting
# 5         224-1879       O16546  Oil painting
# 6        FA.187[O]       O77070  Oil painting
# 7        P.12-1947       O17306  Oil painting
# 8        P.70-1986       O78693  Oil painting
# 9        FA.241[O]       O15091  Oil painting
# 10       P.13-1947       O78664  Oil painting
# 11        FA.99[O]       O80673  Oil painting
# 12        495-1882      O131646  Oil painting
# 13         57-1908       O15099  Oil painting
# 14       1824-1900       O80872  Oil painting
#
#                                         _primaryTitle  _primaryPlace  \
# 0                                          The Spring    Switzerland
# 1                                              Spring            NaN
# 2                                              Spring  Great Britain
# 3   Study for the four seasons: Spring (Daphnis an...         France
# 4                        Spring: East Bergholt Common        England
# 5            Disturbed: A Plover Rising from Its Nest        England
# 6                                      Spring Flowers        Britain
# 7       The Milkmaid's Garland, or Humours of May Day         London
# 8                      Country Dances Round a Maypole         London
# 9                                    The Dawn of Love        England
# 10       The Humorous Diversion of Sliding on the Ice         London
# 11                                           Suspense  Great Britain
# 12                                   L'Amour Oiseleur         France
# 13                                           The Rose        England
# 14        Florence Dombey in Captain Cuttle's Parlour  Great Britain
#
#                 _primaryMaker__name _primaryMaker__association  \
# 0                  Menn, Barthélémy           painter (artist)
# 1             Platzer, Johann Georg                     artist
# 2                     Gertler, Mark           painter (artist)
# 3             Millet, Jean-François                     artist
# 4              Constable, John (RA)                     artist
# 5                Oakes, John Wright                     artist
# 6                     Smith, George                     artist
# 7              Hayman, Francis (RA)           painter (artist)
# 8              Hayman, Francis (RA)           painter (artist)
# 9                    Brooks, Thomas                     artist
# 10             Hayman, Francis (RA)           painter (artist)
# 11  Landseer, Edwin Henry (Sir, RA)                     artist
# 12                Boucher, François                      after
# 13            Parris, Edmond Thomas                     artist
# 14               Egley, William Maw                     artist
#
#         _primaryDate _primaryImageId _sampleMaterial _sampleTechnique  \
# 0           pre 1868      2007BP0651       oil paint     oil painting
# 1           pre 1761      2006BG0261       oil paint     oil painting
# 2               1931      2007BM8274       oil paint     oil painting
# 3        Before 1865      2007BN4453       oil paint     oil painting
# 4           ca. 1814      2006BC6067       oil paint     oil painting
# 5               1879      2006AH8785       oil paint     oil painting
# 6               1851      2006AL8240       oil paint     oil painting
# 7          1741-1742      2006AM5395       oil paint     oil painting
# 8          1741-1742      2006AN2177       oil paint     oil painting
# 9               1846      2006AV0394       oil paint     oil painting
# 10         1741-1742      2006AM8944       oil paint     oil painting
# 11          ca. 1834      2006AM2419       oil paint     oil painting
# 12  mid 19th century      2007BN5337       oil paint              NaN
# 13              1832      2006AN6830          canvas              NaN
# 14              1888      2006AV5006       oil paint     oil painting
#
#        _sampleStyle                      _currentLocation__displayName  \
# 0      Swiss School                                           In store
# 1   Austrian School                                           In store
# 2    British School                                                NaN
# 3     French School  Paintings, Room 81, The Edwin and Susan Davies...
# 4    British School              Prints & Drawings Study Room, room WS
# 5               NaN                                           In store
# 6    British School                        British Galleries, Room 122
# 7    British School                                                NaN
# 8    British School  British Galleries, Room 52, The George Levy Ga...
# 9    British School                                           In store
# 10   British School  British Galleries, Room 52, The George Levy Ga...
# 11   British School                                           In store
# 12    French School                                           In store
# 13   British School                                           In store
# 14   British School  Paintings, Room 82, The Edwin and Susan Davies...
#
#     _objectContentWarning  _imageContentWarning
# 0                   False                 False
# 1                   False                 False
# 2                   False                 False
# 3                   False                 False
# 4                   False                 False
# 5                   False                 False
# 6                   False                 False
# 7                   False                 False
# 8                   False                 False
# 9                   False                 False
# 10                  False                 False
# 11                  False                 False
# 12                  False                 False
# 13                  False                 False
# 14                  False                 False

# %%
import urllib3
import requests
df_louvre_printemps = pd.read_csv("louvre-spring.csv", sep=";")
df_louvre_printemps.sample(5)
# Out:
#             ARK                                  Object name/Title  \
# 7   cl010057734                                       Le Printemps
# 11  cl010061819                              Le Printemps et l'Été
# 30  cl010063038  Vue de Venise. Le Quai des Esclavons et le Pal...
# 14  cl010063616                Rosny. Vue du village au printemps.
# 13  cl010063018          Printemps. East Bergholt Common (Suffolk)
#
#                                     Author                               Date  \
# 7              Boucher, François  ; France                               1753
# 11                  Coypel, Noël  ; France  1660 / 1700 (Fin du XVIIe siècle)
# 30   Bonington, Richard  ; Grande-bretagne                               1826
# 14  Corot, Jean-Baptiste Camille  ; France                               1839
# 13      Constable, John  ; Grande-bretagne                               1840
#
#     Inventory number                 Collection
# 7           INV 2703  Département des Peintures
# 11  INV 3036; B 1746  Département des Peintures
# 30            RF 368  Département des Peintures
# 14           RF 2603  Département des Peintures
# 13           RF 1241  Département des Peintures

# %%
import lineup_widget
import pandas as pd

w = lineup_widget.LineUpWidget(df_louvre_printemps)
w.on_selection_changed(lambda selection: print(selection))
w
# Out:
# LineUpWidget(value=[], layout=Layout(align_self='stretch', height='600px'), options={'filterGlobally': True, '…
