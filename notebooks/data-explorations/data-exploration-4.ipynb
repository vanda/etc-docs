# %% [markdown]
# # 4. Vesuvius Viewsheds Visualised
#
# ```{sidebar} Datasets
#   * [Birmingham Museums](https://www.birminghammuseums.org.uk/) [collections](https://www.birminghammuseums.org.uk/collection)
#   * [V&A](https://collections.vam.ac.uk/) collections
# ```
#
# Recent geothermal events have drawn our attention to historical depictions of the volcano Vesuvius. Let's take a look at artworks in the [Birmingham](https://www.birminghammuseums.org.uk) and [V&A](https://www.vam.ac.uk) collections depicting Vesuvius, asking that all-important question, what historical viewsheds of Vesuvius are there ?

# %% [markdown]
# ```{note}
# Whilst pleasingly alliterative, the proper definition of a viewshed perhaps does not totally match up with the usage here, to show the estimated view of a painting when placed onto a map. Possibly a better definition would be line of sight, but that doesn't have enough V's in it.
# ```

# %% [markdown]
# ## Birmingham Museums Collections
#
# A search for [Naples](https://dams.birminghammuseums.org.uk/asset-bank/action/quickSearch?CSRF=jXaMK3gIfUI8DAvcpikt&newSearch=true&quickSearch=true&includeImplicitCategoryMembers=true&keywords=naples) shows 19 paintings, of which a handful give enough clues in their titles to give a very approximate location to place on a map.

# %% [markdown]
# ## V&A Collections
#
# Searching for Vesuvius in the V&A collections reveals [four watercolours](https://collections.vam.ac.uk/search/?q=vesuvius&images_exist=true&page=1&kw_object_type=Watercolour) we can estimate a location of.

# %% [markdown]
# ```{note}
# Please note, these are estimates of places based on very limited geographical knowledge by the writer of this notebook and is intended as a worked example for data exploration and should not be taken as a serious investigation into vulcanology or art history.
# ```

# %% [markdown]
# To make the notebook reproducable, we've created a small CSV file containing the information needed from both collections, giving 8 artworks to map.
#
# This CSV contains the fields:
#
#   * Holding Collection
#   * Artwork Title
#   * Artwork artist/maker
#   * Artwork date of production (to the year)
#   * Artwork description
#   * Artwork link
#   * Artwork thumbnail
#   * Artwork viewshed lat/lon (estimated by the author of this notebook)
#   * Artwork viewshed direction
#   * Artwork viewshed confidence (marked by self)

# %%
import pandas as pd

vesuvius_df = pd.read_csv('vesuvius.csv')
vesuvius_df["Description"] = vesuvius_df["Description"].astype(str)
vesuvius_df
# Out:
#            Collection                                         Title  \
# 0  Birmingham Museums            The Bay of Naples from Capodimonte
# 1  Birmingham Museums      Naples From Sir William Hamilton's Villa
# 2  Birmingham Museums                  Temple of Venus, Bay of Baia
# 3  Birmingham Museums                                 Near Sorrento
# 4                 V&A                                      Vesuvius
# 5                 V&A  Vesuvius and the Bay of Naples from Posilipo
# 6                 V&A                  Street of the Tombs, Pompeii
# 7                 V&A                                      Vesuvius
#
#                    Maker                                        Description  \
# 0          William Paris  View from a vineyard between the Capodimonte a...
# 1     John Warwick Smith                                                nan
# 2           William Pars                                                nan
# 3             John Brett                                                nan
# 4     John Robert Cozens  Mount Vesuvius; Viewed from the land side; rui...
# 5  John William Inchbold                                Watercolour drawing
# 6         Samuel Palmer"  'Street of the Tombs, Pompeii', showing the ru...
# 7     John Robert Cozens  Vesuvius; a slight volume of smoke issuing fro...
#
#                                                 Link  Thumbnail   Latitude  \
# 0  https://dams.birminghammuseums.org.uk/asset-ba...        NaN  40.858144
# 1  https://dams.birminghammuseums.org.uk/asset-ba...        NaN  40.815083
# 2  https://dams.birminghammuseums.org.uk/asset-ba...        NaN  40.818099
# 3  https://dams.birminghammuseums.org.uk/asset-ba...        NaN  40.634868
# 4  https://collections.vam.ac.uk/item/O1139859/ve...        NaN  40.800000
# 5  https://collections.vam.ac.uk/item/O187904/ves...        NaN  40.811328
# 6   https://collections.vam.ac.uk/item/O126826/st...        NaN  40.746618
# 7   "https://collections.vam.ac.uk/item/O1023498/...        NaN  40.815000
#
#    Longitude  Direction  Confidence
# 0  14.221832        180          70
# 1  14.335572        225          50
# 2  14.071142        225          70
# 3  14.363853        225          75
# 4  14.500000        270          25
# 5  14.183128        225          70
# 6  14.476173        270          50
# 7  14.335000        270          75

# %% [markdown]
# ## Viewshed Mapping
#
# Now we can display these points on on a map. and the viewing angle (as a triangle) they very approximately have, either facing towards (or away) from Vesuvius. For this we are using [leaflet](https://leafletjs.com/) and some hardcoded rules.

# %% [markdown]
# ```{note}
# For reasons unknown, the map below is sometimes showing more than once.
# ```

# %%
from ipyleaflet import Map, basemaps, basemap_to_tiles, GeoJSON, Polygon, Marker, Popup
from ipywidgets import HTML
from IPython.core import display
import numpy

m = Map(
    basemap=basemap_to_tiles(basemaps.OpenStreetMap.Mapnik),
    center=(40.8, 14.41),
    zoom=10
)

for index,obj in vesuvius_df.iterrows():

  origin_viewpoint = numpy.array([obj['Latitude'], obj['Longitude']])

  if obj['Collection'] == "Birmingham Museums":
        polygon_colour = "orange"
  else:
        polygon_colour = "red"

  # This really should be done by some angle calculations that are beyond me, hence just using 90,180,270...
  if obj['Direction'] == 90:
        viewshed_shape = [origin_viewpoint.tolist(), (origin_viewpoint + (-0.02,0.05)).tolist(),
                          (origin_viewpoint + (0.02, 0.05)).tolist()]
  elif obj['Direction'] == 180:
        viewshed_shape = [origin_viewpoint.tolist(), (origin_viewpoint + (-0.05,-0.02)).tolist(),
                          (origin_viewpoint + (-0.05, 0.02)).tolist()]
  elif obj['Direction'] == 270:
        viewshed_shape = [origin_viewpoint.tolist(), (origin_viewpoint + (-0.02,-0.05)).tolist(),
                          (origin_viewpoint + (0.02, -0.05)).tolist()]
  else:
        viewshed_shape = [origin_viewpoint.tolist(), (origin_viewpoint + (-0.02,0.05)).tolist(),
                          (origin_viewpoint + (0.02, 0.05)).tolist()]
        
  polygon = Polygon(
     locations= [ viewshed_shape  ],  color=polygon_colour,  fill_color=polygon_colour,
     stroke=True,  dash_array="4,1,1", weight=2)

  m.add_layer(polygon)

  marker = Marker(location=origin_viewpoint.tolist())
  m.add_layer(marker)

  message1 = HTML()
  message1.value = f'<a href="{obj["Link"]}">{obj["Title"]}</a> '
  if len(obj['Description']) > 0:
    message1.value += obj["Description"]

   # Popup with a given location on the map:
  popup = Popup(
    location=origin_viewpoint.tolist(), child=message1, close_button=True,
    auto_close=True, close_on_escape_key=False
  )
      
#  m.add_layer(popup)
  marker.popup = message1

m.layout.width = '100%'
m.layout.height = '500px'

m.save('vesuvius-viewsheds.html', title='Vesuvius Viewsheds')
display.HTML('vesuvius-viewsheds.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Vesuvius Viewsheds</title>
# </head>
# <body>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://cdn.jsdelivr.net/npm/@jupyter-widgets/html-manager@^1.0.1/dist/embed-amd.js" crossorigin="anonymous"></script>
#
# <script type="application/vnd.jupyter.widget-state+json">
# {
#   "version_major": 2,
#   "version_minor": 0,
#   "state": {
#     "2c8b885a8c014f8c9a0a2f87dd6fad4e": {
#       "model_name": "LeafletTileLayerModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "attribution": "&copy; <a href=\"https://www.openstreetmap.org/copyright\">OpenStreetMap</a> contributors",
#         "base": true,
#         "max_zoom": 19,
#         "min_zoom": 1,
#         "name": "OpenStreetMap.Mapnik",
#         "options": [
#           "attribution",
#           "bounds",
#           "detect_retina",
#           "max_native_zoom",
#           "max_zoom",
#           "min_native_zoom",
#           "min_zoom",
#           "no_wrap",
#           "tile_size",
#           "tms",
#           "zoom_offset"
#         ],
#         "subitems": [],
#         "url": "https://tile.openstreetmap.org/{z}/{x}/{y}.png"
#       }
#     },
#     "a25d407aa6fd4c728236c5d3c612e040": {
#       "model_name": "LeafletMapStyleModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {}
#     },
#     "17321865e9334ff5beb65f0e731b9b96": {
#       "model_name": "LeafletMapStyleModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "cursor": "move"
#       }
#     },
#     "ca769b4759d942b2ad66c43ed8a3344e": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "2.0.0",
#       "state": {
#         "height": "500px",
#         "width": "100%"
#       }
#     },
#     "17e9e42e0cc74483a19563a52f953f6d": {
#       "model_name": "LeafletMapStyleModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {}
#     },
#     "1180bef3c7a74024ba45ec622a48d87a": {
#       "model_name": "LeafletMapModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "_dom_classes": [],
#         "center": [
#           40.8,
#           14.41
#         ],
#         "controls": [
#           "IPY_MODEL_d96bc40e0a314ef38d17d1498a90a79b",
#           "IPY_MODEL_b90e7f4893b24cd998644e030944d836"
#         ],
#         "crs": {
#           "name": "EPSG3857",
#           "custom": false
#         },
#         "default_style": "IPY_MODEL_a25d407aa6fd4c728236c5d3c612e040",
#         "dragging_style": "IPY_MODEL_17321865e9334ff5beb65f0e731b9b96",
#         "layers": [
#           "IPY_MODEL_2c8b885a8c014f8c9a0a2f87dd6fad4e",
#           "IPY_MODEL_31145f39ad544ebe912a0b43b15e88a1",
#           "IPY_MODEL_d96f258a95f441509f747e0440bd9807",
#           "IPY_MODEL_255d47bf00e04dbbaae07cb1e2db2d8c",
#           "IPY_MODEL_094a4b2fe58040dfa0b2720ef8f9ddb6",
#           "IPY_MODEL_d52ee2c00c084195892c5eb6aee60939",
#           "IPY_MODEL_e4ffba24b1eb41ae9dfce8d0df2bc076",
#           "IPY_MODEL_4cfc5eac774a4b5ca43515e2b63ef767",
#           "IPY_MODEL_5f6632647de2479f9383b878a6edd06d",
#           "IPY_MODEL_f9ee1ba24b684befa65279ba8d82ba34",
#           "IPY_MODEL_1d29b3999db046f4b75de3fc4361bcc9",
#           "IPY_MODEL_691e35bb3c474e1bac129565b3fb61b5",
#           "IPY_MODEL_04e9e97fae344c5290b6cfacc117e98c",
#           "IPY_MODEL_3c6453d9eb824188b9397fc8e417d469",
#           "IPY_MODEL_8cd5e04d53644610b639fe15cb1f9faa",
#           "IPY_MODEL_93fbb7e4291446fda5537f078aafe892",
#           "IPY_MODEL_b5b70aa017144574b120302cd926acdf"
#         ],
#         "layout": "IPY_MODEL_ca769b4759d942b2ad66c43ed8a3344e",
#         "options": [
#           "bounce_at_zoom_limits",
#           "box_zoom",
#           "center",
#           "close_popup_on_click",
#           "double_click_zoom",
#           "dragging",
#           "fullscreen",
#           "inertia",
#           "inertia_deceleration",
#           "inertia_max_speed",
#           "interpolation",
#           "keyboard",
#           "keyboard_pan_offset",
#           "keyboard_zoom_offset",
#           "max_zoom",
#           "min_zoom",
#           "prefer_canvas",
#           "scroll_wheel_zoom",
#           "tap",
#           "tap_tolerance",
#           "touch_zoom",
#           "world_copy_jump",
#           "zoom",
#           "zoom_animation_threshold",
#           "zoom_delta",
#           "zoom_snap"
#         ],
#         "panes": {},
#         "style": "IPY_MODEL_17e9e42e0cc74483a19563a52f953f6d",
#         "zoom": 10.0
#       }
#     },
#     "d96bc40e0a314ef38d17d1498a90a79b": {
#       "model_name": "LeafletZoomControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "options": [
#           "position",
#           "zoom_in_text",
#           "zoom_in_title",
#           "zoom_out_text",
#           "zoom_out_title"
#         ]
#       }
#     },
#     "b90e7f4893b24cd998644e030944d836": {
#       "model_name": "LeafletAttributionControlModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "options": [
#           "position",
#           "prefix"
#         ],
#         "position": "bottomright"
#       }
#     },
#     "31145f39ad544ebe912a0b43b15e88a1": {
#       "model_name": "LeafletPolygonModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "color": "orange",
#         "dash_array": "4,1,1",
#         "fill_color": "orange",
#         "locations": [
#           [
#             [
#               40.8581441,
#               14.2218316
#             ],
#             [
#               40.8081441,
#               14.2018316
#             ],
#             [
#               40.8081441,
#               14.2418316
#             ]
#           ]
#         ],
#         "options": [
#           "color",
#           "dash_array",
#           "draggable",
#           "fill",
#           "fill_color",
#           "fill_opacity",
#           "line_cap",
#           "line_join",
#           "no_clip",
#           "opacity",
#           "pointer_events",
#           "smooth_factor",
#           "stroke",
#           "transform",
#           "weight"
#         ],
#         "subitems": [],
#         "weight": 2
#       }
#     },
#     "d96f258a95f441509f747e0440bd9807": {
#       "model_name": "LeafletMarkerModel",
#       "model_module": "jupyter-leaflet",
#       "model_module_version": "^0.19",
#       "state": {
#         "location": [
#           40.8581441,
#           14.2218316
#         ],
#         "options": [
#           "alt",
#           "draggable",
#           "keyboard",
#           "rise_offset",
#           "rise_on_hover",
#           "rotation_angle",
#           "rotation_origin",
#           "title",
#           "z_index_offset"
#         ],
#         "popup": "IPY_MODEL_fc3e9889ca8f41d28fa352849809958b",
#         "subitems": []
#       }
#     },
#     "cafe5bf65f594c2e8eab45335ab92cf3": {
#       "model_name": "LayoutModel",
#       "model_module": "@jupyter-widgets/base",
#       "model_module_version": "2.0.0",
#       "state": {}
#     },
#     "479c7a8dfe1f4bf79714d909386d71bc": {
#       "model_name": "HTMLStyleModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "2.0.0",
#       "state": {}
#     },
#     "fc3e9889ca8f41d28fa352849809958b": {
#       "model_name": "HTMLModel",
#       "model_module": "@jupyter-widgets/controls",
#       "model_module_version": "2.0.0",
#       "state": {
#         "_dom_classes": [],
#         "layout": "IPY_MODEL_cafe5bf65f594c2e8eab45335ab92cf3",
#         "style": "IPY_MODEL_479c7a8dfe1f4bf79714d909386d71bc",
#         "value": "<a href=\"https://dams.birminghammuseums.org.uk/asset-bank/action/viewAsset?id=15910&index=0&total=19&view=viewSearchItem\">The Bay of Naples from Capodimonte</a> View

# %% [markdown]
# ## Future Enhancements
#
#   * Enable timeslide plugin in leaflet (needs to be ported to Jupyter ipyleaflet) to enable showing viewsheds over time
#   * Supress nan values appearing in popups
#   * Have more data assembled by someone who has real knowledge of this topic.
#   * Do this properly in 3D as the [Georgia O'Keeffe Museum](https://web.tplgis.org/gokmuseum/) have done
