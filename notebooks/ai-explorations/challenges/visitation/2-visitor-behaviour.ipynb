# %% [markdown]
# # Visitor Behaviour
#
#
# ## Papers
# https://www.mdpi.com/2076-3417/12/2/533
#
#
#
# ## Bibliography
#
# ### Cultural Heritage
#
# #### 2022
#
#   * Ferrato, A. et al. (2022) ‘Using Deep Learning for Collecting Data about Museum Visitor Behavior’, Applied Sciences, 12(2), p. 533. Available at: https://doi.org/10.3390/app12020533.
